# %% [markdown]
# # ตัวอย่างการขูดข้อมูลด้วย `BeautifulSoup`

# %%
from bs4 import BeautifulSoup
import requests

# %%
def scrape_article(url):
  headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
  page = requests.get(url, headers=headers)
  if page.status_code != 200:
    return 0
  soup = BeautifulSoup(page.content, 'html.parser')
  d_list = soup.select('section#content-area p')
  if len(d_list) == 1:
    t = d_list[0].text
    with open(url.split('/')[-2] + '.txt', mode='w') as f:
      f.write(t)
    return 1
  else:
    print('Found error in {}'.format(url))
    return 0

i = 0
num_pages = 0
while num_pages < 20: 
  url = 'https://www.dek-d.com/board/teen/4042928/'
  prefix, number, _ = url.rsplit('/',2)
  number = str(int(number)- i)
  new_url = prefix + '/' + number +'/'
  num_pages += scrape_article(new_url)
  i += 1
# Out:
# Found error in https://www.dek-d.com/board/teen/4042926/
# Found error in https://www.dek-d.com/board/teen/4042923/
# Found error in https://www.dek-d.com/board/teen/4042913/
# Found error in https://www.dek-d.com/board/teen/4042912/
# Found error in https://www.dek-d.com/board/teen/4042911/
# Found error in https://www.dek-d.com/board/teen/4042909/
# Found error in https://www.dek-d.com/board/teen/4042907/
# Found error in https://www.dek-d.com/board/teen/4042906/
# Found error in https://www.dek-d.com/board/teen/4042905/

# %%
# !zip teen_board.zip *.txt
# Out:
#   adding: 4042900.txt (deflated 45%)
#   adding: 4042901.txt (deflated 18%)
#   adding: 4042902.txt (deflated 41%)
#   adding: 4042903.txt (deflated 66%)
#   adding: 4042904.txt (deflated 76%)
#   adding: 4042908.txt (deflated 51%)
#   adding: 4042910.txt (deflated 45%)
#   adding: 4042914.txt (deflated 58%)
#   adding: 4042915.txt (deflated 49%)
#   adding: 4042916.txt (deflated 38%)
#   adding: 4042917.txt (deflated 37%)
#   adding: 4042918.txt (deflated 51%)
#   adding: 4042919.txt (deflated 50%)
#   adding: 4042920.txt (deflated 62%)
#   adding: 4042921.txt (deflated 39%)
#   adding: 4042922.txt (deflated 38%)
#   adding: 4042924.txt (deflated 39%)
#   adding: 4042925.txt (deflated 61%)
#   adding: 4042927.txt (deflated 56%)
#   adding: 4042928.txt (deflated 61%)
